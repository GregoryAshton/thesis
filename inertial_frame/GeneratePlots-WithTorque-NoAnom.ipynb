# %%
from matplotlib import pyplot as plt
import nsmod
import os 
import numpy as np
from numpy import sin, cos, tan
from matplotlib.ticker import MultipleLocator 
# %matplotlib inline

from nsmod.switching_torque_with_Euler import main
from nsmod import Plot, File_Functions, Model

# %% [markdown]
# # Generating plots for the Inertial space results
# In this notebook all plots for this section are generated. We will use the `nsmod.switching_torque_with_Euler` model with the switching paramater $\upsilon=0$. This reduces the number of models that we need while the speed savings are most likely negligible.

# %% [markdown]
# # Including the torque: no anomalous torque
#
# Focus of cases for which $\epsilon_{A} < \epsilon_I$ e.g Pulsar A

# %%
chi0 = 80
omega0 = 10
epsI3 = 1e-3
epsA = 5e-4
a0 = 15
T = 5e3

file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                 n=10000, error=1e-12, a0=a0, cleanup=False, AnomTorque=False)

axes = Plot.Spherical_Plot(file_name, save_fig=True)
plt.show()

axes = Plot.Euler_Angles(file_name, save_fig=True)
plt.show()
# Out:
# WARNING: File already exists and cleanup=False
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_8.0000000000e+01_omega0_1.00e+01_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_1.5000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# Saving figure as ./img/Spherical_Plot_Unknown_SpindownTorqueSwitching_1_chi0_8.0000000000e+01_omega0_1.00e+01_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_1.5000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.pdf
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_8.0000000000e+01_omega0_1.00e+01_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_1.5000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_8.0000000000e+01_omega0_1.00e+01_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_1.5000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# Saving figure as ./img/Euler_Angles_Unknown_SpindownTorqueSwitching_1_chi0_8.0000000000e+01_omega0_1.00e+01_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_1.5000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.pdf

# %% [markdown]
# ## Without anomalous: Frequency and phase

# %%
a0 = 20
epsI3 = 1e-3
omega0 = 1 * 2 * np.pi
epsA = 5e-4
T = 5e3

a0_rad = np.radians(a0)
theta_0 = np.arccos(cos(a0_rad) * (1 + epsI3) * pow(pow(sin(a0_rad), 2) 
                            + pow(cos(a0_rad) * (1 + epsI3), 2), -0.5))

chi0_list = [10.0, 20.0, 80.0]
label_list = [r"$\chi=\theta/2$", r"$\chi=\theta$", r"$\chi= 4\theta$"]
color_list = ["b", "r", "g"]
#chi_list = [np.degrees(theta_0)]
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)

fig2 = plt.figure()
ax2 = fig2.add_subplot(111)

for i, chi0 in enumerate(chi0_list):
    file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T, 
                     n=1000, error=1e-14, a0=a0, cleanup=True, AnomTorque=False)
    
    time, w1, w2, w3, theta, phi, psi = nsmod.File_Functions.Euler_Angles_Import(file_name)
    (t_scaled, scale_val) = nsmod.Useful_Tools.Sort_Out_Some_Axis(time)

    ax1 = nsmod.Plot.big_phi_dot(file_name, ax=ax1, label=label_list[i], color=color_list[i])

    ax2 = nsmod.Plot.big_theta(file_name, ax=ax2, label=label_list[i], color=color_list[i])
    
# Add horizontal lines to ax1; note phi dot is the same regardless of chi
xfit, yfit, f_p = nsmod.Useful_Tools.Fit_Function(time, phi, 1)
phi_dot = f_p[0]
ax1.axhline(phi_dot, ls="--", color="k",) #label=r"$\dot{\phi}$")
ax1.text(0.95*ax1.get_xlim()[1], 1.0001*(phi_dot), r"$\dot{\phi}$", size=22)
xfit, yfit, f_p = nsmod.Useful_Tools.Fit_Function(time, psi, 1)
psi_dot = f_p[0]
#ax1.axhline(phi_dot+psi_dot, ls="-.", color="k", )#label=r"$\dot{\phi}+ \dot{\psi}$")
#ax1.text(0.9*ax1.get_xlim()[1], 0.9998*(phi_dot+psi_dot), r"$\dot{\phi}+ \dot{\psi}$", size=22)

delta = 0.03
ax1.set_ylim(6.285-delta, 6.285+delta)
ax1.legend(framealpha=0.7, loc=2, ncol=1)
fig1.savefig("img/frequency_variation_with_chi_inc_torque.pdf")

# Add horizontal lines tp ax2; note psi dot is the same regardless of chi
ax2.set_yticks([10.0, 20.0,30,40, 60.0,80.0, 100])
ax2.set_yticklabels([r"$\theta/2$", r"$\theta$", r"$3\theta/2$", r"$2\theta$", r"$3\theta$", r"$4\theta$", r"$5\theta$"])
ax2.grid(True, axis='y')
ax2.legend(framealpha=0.9, loc=1)
fig2.savefig("img/polar_angle_variation_with_chi_inc_torque.pdf")

plt.show()
# Out:
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_1.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_1000_a0_2.0000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_1.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_1000_a0_2.0000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_1.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_1000_a0_2.0000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_2.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_1000_a0_2.0000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_2.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_1000_a0_2.0000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_2.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_1000_a0_2.0000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_8.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_1000_a0_2.0000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_8.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_1000_a0_2.0000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_8.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_1000_a0_2.0000000000e+01_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED

# %% [markdown]
# ## Without anomalous torque: Timing residuals

# %%
a0 = 2
epsI3 = 1e-3
omega0 = 2 * np.pi
epsA = 5e-4
T = 5e3
AnomTorque=False

a0_rad = np.radians(a0)
theta_0 = np.arccos(cos(a0_rad) * (1 + epsI3) * pow(pow(sin(a0_rad), 2) 
                            + pow(cos(a0_rad) * (1 + epsI3), 2), -0.5))

chi0_list = [10.0, np.degrees(theta_0), 80.0]
label_list = [r"$\chi=\theta/2$", r"$\chi=\theta$", r"$\chi= 4\theta$", "something else"]
color_list = ["b", "r", "g", "k"]

fig1 = plt.figure()
ax_1 = fig1.add_subplot(111, yticklabels=[], xticklabels=[], ylabel="Timing residual")
ax_1.yaxis.labelpad = 30
ax11 = fig1.add_subplot(311)
ax12 = fig1.add_subplot(312)
ax13 = fig1.add_subplot(313)

fig2 = plt.figure()
ax_2 = fig2.add_subplot(111, yticklabels=[], xticklabels=[], ylabel=r"$\dot{\nu}$")
ax_2.yaxis.labelpad = 30
ax21 = fig2.add_subplot(311)
ax22 = fig2.add_subplot(312)
ax23 = fig2.add_subplot(313)

        

for chi0, label, color, ax1, ax2 in zip(chi0_list, label_list, color_list, 
                                        [ax11, ax12, ax13], 
                                        [ax21, ax22, ax23] ):
    
    file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T,
                     AnomTorque=AnomTorque,
                     n=10000, error=1e-16, a0=a0, cleanup=True)
    
    ax1 = Plot.PhaseResidual(file_name, ax=ax1,
                             label=label, color=color)
    
    ax2 = Plot.SpindownRate(file_name, ax=ax2, normalise=True,
                                    label=label, color=color)
   
    ax1.set_ylabel("")
    #ax1.set_yticklabels([])
    ax1.legend()
    ax2.set_ylabel("")
    #ax2.set_yticklabels([])
    ax2.legend()
    
ax11.set_xticklabels([]) 
ax12.set_xticklabels([])
fig1.subplots_adjust(hspace=0.0)
#ax1.axhline(0.0, ls="-", color="k", lw=.5)    
#ax1.legend(framealpha=0.9, loc=1)
fig1.savefig("img/Timing_residuals_with_torque_no_anom.pdf")

ax21.set_xticklabels([]) 
ax22.set_xticklabels([])
fig2.subplots_adjust(hspace=0.0)
#ax2.legend(framealpha=0.9, loc=1)
fig2.savefig("img/nu_dot_with_torque_no_anom.pdf")

plt.show()
# Out:
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_1.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_2.0000000000e+00_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_1.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_2.0000000000e+00_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_1.9980036182e+00_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_2.0000000000e+00_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_1.9980036182e+00_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_2.0000000000e+00_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_8.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_2.0000000000e+00_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# ./data/Unknown_SpindownTorqueSwitching_1_chi0_8.0000000000e+01_omega0_6.28e+00_epsI3_1.00e-03_AnomTorqueSwitching_1_n_10000_a0_2.0000000000e+00_T_5.00e+03_upsilon_0.00e+00_epsA_5.00e-04_epsI1_0.00e+00_AnomTorque_0.hdf5
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED

# %%
File_Functions.PrintParameterDictionary(file_name)
# Out:
# BETA FUNCTION IS USED
# BETA FUNCTION IS USED
# AnomTorque : 0.0000000000e+00
# AnomTorqueSwitching : 1.0000000000e+00
# Bs : 4.2426406871e+16
# DeltaPhi_49 : 1.6443875742e-02
# DeltaPhi_49_SpindownTorque : 7.7383764159e-05
# DeltaPhi_63 : 2.2256364960e-03
# DeltaPhi_75 : 2.9428009477e-04
# DeltaPhi_TS : -0.0000000000e+00
# EMtorqueAmplificationfactor : 4.2520652523e-01
# P : 1.0005072145e+00
# SpindownTorqueSwitching : 1.0000000000e+00
# T : 5.0000000000e+03
# a0 : 2.0000000000e+00
# beta : -3.3181362942e+00
# beta30 : -1.5000000000e+01
# beta75 : -4.9480453195e+00
# chi0 : 8.0000000000e+01
# delta_omega_dot0_EM : 4.3798229347e-07
# delta_omega_dot0_FP : 2.4274227718e-07
# delta_omega_dot0_FP_EM : 3.2854545954e-08
# epsA : 5.0000000000e-04
# epsI1 : 0.0000000000e+00
# epsI3 : 1.0000000000e-03
# n : 1.0000000000e+04
# nu_dot0 : -4.2477551134e-07
# omega0 : 6.2800000000e+00
# omega_dot0 : -2.6689432517e-06
# source_script : Unknown
# tauA : 2.0010144290e+03
# tauE : 2.3529912058e+06
# tauP : 1.0005072145e+03
# tauS : 2.2820398393e+06
# upsilon : 0.0000000000e+00
# wobble_angle : 9.3257853538e-02
# wobble_angle_spindown : 4.3886513481e-04

# %%
a0 = 2
epsI3 = 1e-3
omega0 = 100 * 2 * np.pi
epsA = 5e-4
T = 5e3
AnomTorque=False

a0_rad = np.radians(a0)
theta_0 = np.arccos(cos(a0_rad) * (1 + epsI3) * pow(pow(sin(a0_rad), 2) 
                            + pow(cos(a0_rad) * (1 + epsI3), 2), -0.5))

chi0_list = [10.0, np.degrees(theta_0), 80.0]
label_list = [r"$\chi=\theta/2$", r"$\chi=\theta$", r"$\chi= 4\theta$", "something else"]
color_list = ["b", "r", "g", "k"]

fig1 = plt.figure()
ax_1 = fig1.add_subplot(111, yticklabels=[], xticklabels=[], ylabel="Timing residual")
ax_1.yaxis.labelpad = 30
ax11 = fig1.add_subplot(311)
ax12 = fig1.add_subplot(312)
ax13 = fig1.add_subplot(313)

fig2 = plt.figure()
ax_2 = fig2.add_subplot(111, yticklabels=[], xticklabels=[], ylabel=r"$\dot{\nu}$")
ax_2.yaxis.labelpad = 30
ax21 = fig2.add_subplot(311)
ax22 = fig2.add_subplot(312)
ax23 = fig2.add_subplot(313)

        

for chi0, label, color, ax1, ax2 in zip(chi0_list, label_list, color_list, 
                                        [ax11, ax12, ax13], 
                                        [ax21, ax22, ax23] ):
    
    file_name = main(chi0=chi0, epsI3=epsI3, epsA=epsA, omega0=omega0, T=T,
                     AnomTorque=AnomTorque,
                     n=10000, error=1e-16, a0=a0, cleanup=False)
    
    ax1 = Plot.timing_residual(file_name, ax=ax1, analytic="FP",
                                    label=label, color=color)
    
    #ax2 = Plot.nu_dot(file_name, ax=ax2, normalise=True,
    #                                label=label, color=color)
   
    ax1.set_ylabel("")
    #ax1.set_yticklabels([])
    ax1.legend()
    ax2.set_ylabel("")
    #ax2.set_yticklabels([])
    ax2.legend()
    
ax11.set_xticklabels([]) 
ax12.set_xticklabels([])
fig1.subplots_adjust(hspace=0.0)
#ax1.axhline(0.0, ls="-", color="k", lw=.5)    
#ax1.legend(framealpha=0.9, loc=1)
#fig1.savefig("img/Timing_residuals_with_torque_no_anom.pdf")

ax21.set_xticklabels([]) 
ax22.set_xticklabels([])
fig2.subplots_adjust(hspace=0.0)
#ax2.legend(framealpha=0.9, loc=1)
#fig2.savefig("img/nu_dot_with_torque_no_anom.pdf")

File_Functions.PrintParameterDictionary(file_name)
plt.show()
# Out:
# WARNING: File already exists and cleanup=False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-c58b0fccdae9> in <module>()
#      38                      n=10000, error=1e-16, a0=a0, cleanup=False)
#      39
# ---> 40     ax1 = Plot.timing_residual(file_name, ax=ax1, analytic="FP",
#      41                                     label=label, color=color)
#      42
#
# AttributeError: 'module' object has no attribute 'timing_residual'
